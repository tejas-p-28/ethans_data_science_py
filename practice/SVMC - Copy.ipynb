# %% [markdown]
# # Importing all the necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Reading the comma separated values file into the dataframe

# %%
df = pd.read_csv('/content/drive/MyDrive/Lecture Notebooks/Datasets/voice.csv')
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
df.label
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 3163    female
# 3164    female
# 3165    female
# 3166    female
# 3167    female
# Name: label, Length: 3168, dtype: object

# %% [markdown]
# # Checking the correlation between each feature

# %%
df.corr()
# Out:
# <ipython-input-6-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# minfun    0.383937 -0.345609  0.337602  0.320994  0.258002 -0.222680
# maxfun    0.274004 -0.129662  0.251328  0.199841  0.285584 -0.069588
# meandom   0.536666 -0.482726  0.455943  0.467403  0.359181 -0.333362
# mindom    0.229261 -0.357667  0.191169  0.302255 -0.023750 -0.357037
# maxdom    0.519528 -0.482278  0.438919  0.459683  0.335114 -0.337877
# dfrange   0.515570 -0.475999  0.435621  0.454394  0.335648 -0.331563
# modindx  -0.216979  0.122660 -0.213298 -0.141377 -0.216475  0.041252
#
#               skew      kurt    sp.ent       sfm      mode  centroid  \
# meanfreq -0.322327 -0.316036 -0.601203 -0.784332  0.687715  1.000000
# sd        0.314597  0.346241  0.716620  0.838086 -0.529150 -0.739039
# median   -0.257407 -0.243382 -0.502005 -0.661690  0.677433  0.925445
# Q25      -0.319475 -0.350182 -0.648126 -0.766875  0.591277  0.911416
# Q75      -0.206339 -0.148881 -0.174905 -0.378198  0.486857  0.740997
# IQR       0.249497  0.316185  0.640813  0.663601 -0.403764 -0.627605
# skew      1.000000  0.977020 -0.195459  0.079694 -0.434859 -0.322327
# kurt      0.977020  1.000000 -0.127644  0.109884 -0.406722 -0.316036
# sp.ent   -0.195459 -0.127644  1.000000  0.866411 -0.325298 -0.601203
# sfm       0.079694  0.109884  0.866411  1.000000 -0.485913 -0.784332
# mode     -0.434859 -0.406722 -0.325298 -0.485913  1.000000  0.687715
# centroid -0.322327 -0.316036 -0.601203 -0.784332  0.687715  1.000000
# meanfun  -0.167668 -0.194560 -0.513194 -0.421066  0.324771  0.460844
# minfun   -0.216954 -0.203201 -0.305826 -0.362100  0.385467  0.383937
# maxfun   -0.080861 -0.045667 -0.120738 -0.192369  0.172329  0.274004
# meandom  -0.336848 -0.303234 -0.293562 -0.428442  0.491479  0.536666
# mindom   -0.061608 -0.103313 -0.294869 -0.289593  0.198150  0.229261
# maxdom   -0.305651 -0.274500 -0.324253 -0.436649  0.477187  0.519528
# dfrange  -0.304640 -0.272729 -0.319054 -0.431580  0.473775  0.515570
# modindx  -0.169325 -0.205539  0.198074  0.211477 -0.182344 -0.216979
#
#            meanfun    minfun    maxfun   meandom    mindom    maxdom  \
# meanfreq  0.460844  0.383937  0.274004  0.536666  0.229261  0.519528
# sd       -0.466281 -0.345609 -0.129662 -0.482726 -0.357667 -0.482278
# median    0.414909  0.337602  0.251328  0.455943  0.191169  0.438919
# Q25       0.545035  0.320994  0.199841  0.467403  0.302255  0.459683
# Q75       0.155091  0.258002  0.285584  0.359181 -0.023750  0.335114
# IQR      -0.534462 -0.222680 -0.069588 -0.333362 -0.357037 -0.337877
# skew     -0.167668 -0.216954 -0.080861 -0.336848 -0.061608 -0.305651
# kurt     -0.194560 -0.203201 -0.045667 -0.303234 -0.103313 -0.274500
# sp.ent   -0.513194 -0.305826 -0.120738 -0.293562 -0.294869 -0.324253
# sfm      -0.421066 -0.362100 -0.192369 -0.428442 -0.289593 -0.436649
# mode      0.324771  0.385467  0.172329  0.491479  0.198150  0.477187
# centroid  0.460844  0.383937  0.274004  0.536666  0.229261  0.519528
# meanfun   1.000000  0.339387  0.311950  0.270840  0.162163  0.277982
# minfun    0.339387  1.000000  0.213987  0.375979  0.082015  0.317860
# maxfun    0.311950  0.213987  1.000000  0.337553 -0.243426  0.355390
# meandom   0.270840  0.375979  0.337553  1.000000  0.099656  0.812838
# mindom    0.162163  0.082015 -0.243426  0.099656  1.000000  0.026640
# maxdom    0.277982  0.317860  0.355390  0.812838  0.026640  1.000000
# dfrange   0.275154  0.316486  0.359880  0.811304  0.008666  0.999838
# modindx  -0.054858  0.002042 -0.363029 -0.180954  0.200212 -0.425531
#
#            dfrange   modindx
# meanfreq  0.515570 -0.216979
# sd       -0.475999  0.122660
# median    0.435621 -0.213298
# Q25       0.454394 -0.141377
# Q75       0.335648 -0.216475
# IQR      -0.331563  0.041252
# skew     -0.304640 -0.169325
# kurt     -0.272729 -0.205539
# sp.ent   -0.319054  0.198074
# sfm      -0.431580  0.211477
# mode      0.473775 -0.182344
# centroid  0.515570 -0.216979
# meanfun   0.275154 -0.054858
# minfun    0.316486  0.002042
# maxfun    0.359880 -0.363029
# meandom   0.811304 -0.180954
# mindom    0.008666  0.200212
# maxdom    0.999838 -0.425531
# dfrange   1.000000 -0.429266
# modindx  -0.429266  1.000000

# %% [markdown]
# # Checking whether there is any null values

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (3168, 21)

# %%
print("Total number of labels: {}".format(df.shape[0]))
print("Number of male: {}".format(df[df.label == 'male'].shape[0]))
print("Number of female: {}".format(df[df.label == 'female'].shape[0]))
# Out:
# Total number of labels: 3168
# Number of male: 1584
# Number of female: 1584

# %% [markdown]
# Thus we can see there are equal number of male and female labels

# %%
df.shape
# Out:
# (3168, 21)

# %% [markdown]
# There are 21 features and 3168 instances.

# %% [markdown]
# # Separating features and labels

# %%
X=df.iloc[:, :-1]
X.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274

# %% [markdown]
# # Converting string value to int type for labels

# %%
from sklearn.preprocessing import LabelEncoder
y=df.iloc[:,-1]

# Encode label category
# male -> 1
# female -> 0

gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# # Data Standardisation
# Standardization refers to shifting the distribution of each attribute to have a mean of zero and a standard deviation of one (unit variance). It is useful to standardize attributes for a model. Standardization of datasets is a common requirement for many machine learning estimators implemented in scikit-learn; they might behave badly if the individual features do not more or less look like standard normally distributed data.

# %%
# Scale the data to be between -1 and 1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# # Splitting dataset into training set and testing set for better generalisation

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# # Running SVM with default hyperparameter.

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc=SVC() #Default hyperparameters
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9763406940063092

# %% [markdown]
# # Default Linear kernel

# %%
svc=SVC(kernel='linear')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9779179810725552

# %% [markdown]
# # Default RBF kernel

# %%
svc=SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9763406940063092

# %% [markdown]
# We can conclude from above that svm by default uses **rbf** kernel as a parameter for kernel

# %% [markdown]
# # Default Polynomial kernel

# %%
svc=SVC(kernel='poly')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9589905362776026

# %% [markdown]
# Polynomial kernel is performing poorly.The reason behind this maybe it is overfitting the training dataset

# %% [markdown]
# # Performing K-fold cross validation with different kernels

# %% [markdown]
# # CV on Linear kernel and RBF

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear','rbf']}

grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3)

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.961 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.720 total time=   0.3s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.761 total time=   0.3s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.708 total time=   0.3s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.736 total time=   0.3s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.733 total time=   0.3s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.961 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.974 total time=   0.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.959 total time=   0.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.961 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.980 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.959 total time=   0.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.951 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.949 total time=   0.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.951 total time=   0.1s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.966 total time=   0.1s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.961 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.890 total time=   0.3s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.872 total time=   0.2s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.884 total time=   0.2s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.893 total time=   0.3s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.887 total time=   0.2s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.961 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.4s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.6s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.6s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   0.6s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.502 total time=   0.7s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.980 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.968 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.964 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.972 total time=   0.1s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.974 total time=   1.3s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.976 total time=   1.5s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.970 total time=   0.5s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.984 total time=   0.5s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.980 total time=   0.5s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.980 total time=   0.1s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.968 total time=   0.1s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.964 total time=   0.1s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.1s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.974 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.1s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.964 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.982 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.970 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.964 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.982 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.957 total time=   0.1s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.949 total time=   0.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.980 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.968 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.964 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.982 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.972 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.890 total time=   0.2s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.874 total time=   0.2s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.886 total time=   0.2s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.899 total time=   0.2s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.887 total time=   0.2s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.980 total time=   0.2s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.964 total time=   0.1s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.961 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.974 total time=   0.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.974 total time=   0.3s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.976 total time=   0.3s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   0.3s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.988 total time=   0.3s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.980 total time=   0.3s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.980 total time=   0.2s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.964 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.961 total time=   0.1s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.974 total time=   0.1s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.990 total time=   0.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.980 total time=   0.2s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.964 total time=   0.1s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.961 total time=   0.1s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.974 total time=   0.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.974 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.972 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.980 total time=   0.2s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.964 total time=   0.1s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.961 total time=   0.2s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.974 total time=   0.1s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.972 total time=   0.1s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.974 total time=   0.1s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.980 total time=   0.2s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.964 total time=   0.1s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.961 total time=   0.2s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.982 total time=   0.1s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.974 total time=   0.1s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.953 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.943 total time=   0.1s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.980 total time=   1.6s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.966 total time=   1.2s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.961 total time=   1.2s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.980 total time=   1.4s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.974 total time=   0.9s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.974 total time=   0.3s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.976 total time=   0.3s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   0.3s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.988 total time=   0.3s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.980 total time=   0.3s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.980 total time=   1.2s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.966 total time=   0.7s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.961 total time=   0.7s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.980 total time=   0.9s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.974 total time=   0.9s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.972 total time=   0.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.1s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.980 total time=   1.2s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.966 total time=   0.7s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.961 total time=   0.7s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.980 total time=   1.3s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.974 total time=   1.6s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.974 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.970 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.980 total time=   2.0s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.966 total time=   0.7s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.961 total time=   0.7s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.980 total time=   0.9s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.974 total time=   0.9s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.978 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.966 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.978 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.980 total time=   1.1s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.966 total time=   0.7s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.961 total time=   0.7s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.980 total time=   0.9s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.974 total time=   0.9s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.970 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.980 total time=  10.3s
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.966 total time=   7.3s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.961 total time=   8.4s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.980 total time=   6.9s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.974 total time=  12.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.974 total time=   0.3s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.976 total time=   0.3s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.968 total time=   0.3s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.988 total time=   0.4s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.980 total time=   0.5s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.980 total time=   9.8s
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.966 total time=   9.8s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.961 total time=   6.9s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.980 total time=   8.2s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.974 total time=  11.1s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.972 total time=   0.1s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.1s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.1s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.980 total time=   9.0s
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.966 total time=   9.2s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.961 total time=   6.8s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.980 total time=   8.1s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.974 total time=  11.4s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.976 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.980 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.978 total time=   0.1s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.980 total time=   8.6s
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.966 total time=   9.1s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.961 total time=   6.9s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.980 total time=   8.1s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.974 total time=  13.5s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.978 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.974 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.982 total time=   0.1s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.980 total time=   8.3s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.966 total time=  13.9s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.961 total time=  13.0s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.980 total time=   8.9s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.974 total time=  14.5s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.972 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.961 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.972 total time=   0.0s
# GridSearchCV(estimator=SVC(kernel='poly'),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %% [markdown]
# #Let us perform Grid search technique to find the best parameter

# %%
from sklearn.svm import SVC
svm_model= SVC()

# %%
tuned_parameters = {
 'C': (np.arange(0.1,1,0.1)) , 'kernel': ['linear'],
 'C': (np.arange(0.1,1,0.1)) , 'gamma': [0.01,0.02,0.03], 'kernel': ['rbf'],
 'degree': [2,3,4] ,'gamma':[0.01,0.02,0.03], 'C':(np.arange(0.1,1,0.1)) , 'kernel':['poly']
                   }

# %%
from sklearn.model_selection import GridSearchCV

model_svm = GridSearchCV(svm_model, tuned_parameters,cv=10,scoring='accuracy')

# %%
model_svm.fit(X_train, y_train)
print(model_svm.best_score_)
# Out:
# 0.9569745728424264

# %%
#print(model_svm.grid_scores_)

# %%
print(model_svm.best_params_)
# Out:
# {'C': 0.9, 'degree': 3, 'gamma': 0.05, 'kernel': 'poly'}

# %%
svc=SVC(C= 0.9, degree= 3, gamma= 0.05, kernel='linear')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9779179810725552
